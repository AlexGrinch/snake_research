# %%
import os
import time
import random
import numpy as np

import tensorflow as tf
import tensorflow.contrib.layers as layers

import gym
from gym import spaces
from PIL import Image
from collections import deque, namedtuple

from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /root/miniconda3/envs/tf/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from new_agents import *

from atari_wrappers import wrap_deepmind

# %%
game_id = "PongNoFrameskip-v4"
env = wrap_deepmind(gym.make(game_id), clip_rewards=False)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.

# %%
aa = GMMDQNAgent(env=env, num_actions=6, convs=[[32, 8, 4], [64, 4, 2], [64, 3, 1]], 
                 fully_connected=[512], state_shape=[84, 84, 4], save_path="atari_models", model_name="test")

# %%
aa.set_parameters(max_episode_length=5000, replay_memory_size=100000, replay_start_size=10000,
                  discount_factor=0.999, final_eps=0.01, annealing_steps=300000)
# Out:
# WARN: <class 'atari_wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.

# %%
aa.train(gpu_id=6, exploration="e-greedy", save_freq=1000000, max_num_epochs=1000, tau=1e-3, performance_print_freq=10, batch_size=32)
# Out:
# frame count: 8885
# average reward: -20.4
# epsilon: 0.971
# average lifetime: 888.5
# -------------------------------
# frame count: 18221
# average reward: -20.4
# epsilon: 0.94
# average lifetime: 933.6
# -------------------------------
# frame count: 27185
# average reward: -20.5
# epsilon: 0.91
# average lifetime: 896.4
# -------------------------------
# frame count: 36089
# average reward: -20.3
# epsilon: 0.881
# average lifetime: 890.4
# -------------------------------
# frame count: 45124
# average reward: -20.7
# epsilon: 0.851
# average lifetime: 903.5
# -------------------------------
# frame count: 53693
# average reward: -20.5
# epsilon: 0.823
# average lifetime: 856.9
# -------------------------------
# frame count: 62822
# average reward: -20.2
# epsilon: 0.793
# average lifetime: 912.9
# -------------------------------
# frame count: 72194
# average reward: -20.0
# epsilon: 0.762
# average lifetime: 937.2
# -------------------------------
# frame count: 81783
# ...
