# %% [markdown]
# # Imports

# %%
import os
import time
import random
import numpy as np

import tensorflow as tf
import tensorflow.contrib.layers as layers

import gym
from gym import spaces
from PIL import Image
from collections import deque, namedtuple

from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from environments import Snake
from methods import QNetwork, ReplayMemory
from agents import SnakeDuelDQNAgent

# %% [markdown]
# # NN training

# %%
aa = SnakeDuelDQNAgent(model_name="dueldqn_grid8x8", state_shape=[8, 8, 3], fully_connected=[64])

# %%
aa.set_parameters(max_episode_length=2000, replay_memory_size=100000, replay_start_size=10000,
                  discount_factor=1, final_eps=0.01, annealing_steps=500000)

# %%
aa.train(gpu_id=2, batch_size=32, from_epoch=0)
# Out:
# frame count: 4844
# average reward: -0.85
# epsilon: 0.99
# average lifetime: 9.688
# -------------------------------
# frame count: 9443
# average reward: -0.896
# epsilon: 0.981
# average lifetime: 9.198
# -------------------------------
# frame count: 14218
# average reward: -0.884
# epsilon: 0.972
# average lifetime: 9.55
# -------------------------------
# frame count: 18686
# average reward: -0.874
# epsilon: 0.963
# average lifetime: 8.936
# -------------------------------
# frame count: 23306
# average reward: -0.91
# epsilon: 0.954
# average lifetime: 9.24
# -------------------------------
# frame count: 28143
# average reward: -0.858
# epsilon: 0.944
# average lifetime: 9.674
# -------------------------------
# frame count: 33192
# average reward: -0.866
# epsilon: 0.934
# average lifetime: 10.098
# -------------------------------
# frame count: 37993
# average reward: -0.85
# epsilon: 0.925
# average lifetime: 9.602
# -------------------------------
# frame count: 42709
# average reward: -0.864
# epsilon: 0.915
# average lifetime: 9.432
# -------------------------------
# frame count: 47482
# average reward: -0.892
# epsilon: 0.906
# average lifetime: 9.546
# -------------------------------
# frame count: 51982
# average reward: -0.896
# epsilon: 0.897
# average lifetime: 9.0
# -------------------------------
# frame count: 56951
# average reward: -0.864
# epsilon: 0.887
# average lifetime: 9.938
# -------------------------------
# frame count: 61776
# average reward: -0.888
# epsilon: 0.878
# average lifetime: 9.65
# -------------------------------
# frame count: 66450
# average reward: -0.84
# epsilon: 0.868
# average lifetime: 9.348
# -------------------------------
# frame count: 71682
# average reward: -0.854
# epsilon: 0.858
# average lifetime: 10.464
# -------------------------------
# frame count: 76982
# average reward: -0.868
# epsilon: 0.848
# average lifetime: 10.6
# -------------------------------
# frame count: 81871
# average reward: -0.844
# epsilon: 0.838
# average lifetime: 9.778
# -------------------------------
# frame count: 87310
# average reward: -0.832
# epsilon: 0.827
# average lifetime: 10.878
# -------------------------------
# frame count: 92566
# average reward: -0.84
# epsilon: 0.817
# average lifetime: 10.512
# -------------------------------
# frame count: 98029
# average reward: -0.846
# epsilon: 0.806
# average lifetime: 10.926
# -------------------------------
# frame count: 103287
# average reward: -0.848
# epsilon: 0.795
# average lifetime: 10.516
# -------------------------------
# frame count: 108571
# average reward: -0.828
# epsilon: 0.785
# average lifetime: 10.568
# -------------------------------
# frame count: 114057
# average reward: -0.812
# epsilon: 0.774
# average lifetime: 10.972
# -------------------------------
# frame count: 119479
# average reward: -0.836
# epsilon: 0.763
# average lifetime: 10.844
# -------------------------------
# frame count: 124734
# average reward: -0.784
# epsilon: 0.753
# average lifetime: 10.51
# -------------------------------
# frame count: 129746
# average reward: -0.798
# epsilon: 0.743
# average lifetime: 10.024
# -------------------------------
# frame count: 135752
# average reward: -0.762
# epsilon: 0.731
# average lifetime: 12.012
# -------------------------------
# frame count: 142054
# average reward: -0.742
# epsilon: 0.719
# average lifetime: 12.604
# -------------------------------
# frame count: 148036
# average reward: -0.72
# epsilon: 0.707
# average lifetime: 11.964
# -------------------------------
# frame count: 154728
# average reward: -0.69
# epsilon: 0.694
# average lifetime: 13.384
# -------------------------------
# frame count: 161441
# average reward: -0.642
# epsilon: 0.68
# average lifetime: 13.426
# -------------------------------
# frame count: 168276
# average reward: -0.636
# epsilon: 0.667
# average lifetime: 13.67
# -------------------------------
# frame count: 174861
# average reward: -0.66
# epsilon: 0.654
# average lifetime: 13.17
# -------------------------------
# frame count: 181745
# average reward: -0.62
# epsilon: 0.64
# average lifetime: 13.768
# -------------------------------
# frame count: 188424
# average reward: -0.56
# epsilon: 0.627
# average lifetime: 13.358
# -------------------------------
# frame count: 195259
# average reward: -0.538
# epsilon: 0.613
# average lifetime: 13.67
# -------------------------------
# frame count: 202586
# average reward: -0.442
# epsilon: 0.599
# average lifetime: 14.654
# -------------------------------
# frame count: 210479
# average reward: -0.364
# epsilon: 0.583
# average lifetime: 15.786
# -------------------------------
# frame count: 217919
# average reward: -0.432
# epsilon: 0.569
# average lifetime: 14.88
# -------------------------------
# frame count: 225199
# average reward: -0.34
# epsilon: 0.554
# average lifetime: 14.56
# -------------------------------
# frame count: 232699
# average reward: -0.294
# epsilon: 0.539
# average lifetime: 15.0
# -------------------------------
# frame count: 239898
# average reward: -0.336
# epsilon: 0.525
# average lifetime: 14.398
# -------------------------------
# frame count: 248435
# average reward: -0.296
# epsilon: 0.508
# average lifetime: 17.074
# -------------------------------
# frame count: 256075
# average reward: -0.29
# epsilon: 0.493
# average lifetime: 15.28
# -------------------------------
# frame count: 264752
# average reward: -0.234
# epsilon: 0.476
# average lifetime: 17.354
# -------------------------------
# frame count: 273143
# average reward: -0.17
# epsilon: 0.459
# average lifetime: 16.782
# -------------------------------
# frame count: 281630
# average reward: -0.24
# epsilon: 0.442
# average lifetime: 16.974
# -------------------------------
# frame count: 290059
# average reward: -0.11
# epsilon: 0.426
# average lifetime: 16.858
# -------------------------------
# frame count: 299019
# average reward: -0.066
# epsilon: 0.408
# average lifetime: 17.92
# -------------------------------
# frame count: 307896
# average reward: 0.042
# epsilon: 0.39
# average lifetime: 17.754
# -------------------------------
# frame count: 316988
# average reward: 0.062
# epsilon: 0.372
# average lifetime: 18.184
# -------------------------------
# frame count: 326205
# average reward: 0.038
# epsilon: 0.354
# average lifetime: 18.434
# -------------------------------
# frame count: 337024
# average reward: 0.258
# epsilon: 0.333
# average lifetime: 21.638
# -------------------------------
# frame count: 348795
# average reward: 0.354
# epsilon: 0.309
# average lifetime: 23.542
# -------------------------------
# frame count: 360545
# average reward: 0.406
# epsilon: 0.286
# average lifetime: 23.5
# -------------------------------
# frame count: 372774
# average reward: 0.556
# epsilon: 0.262
# average lifetime: 24.458
# -------------------------------
# frame count: 385253
# average reward: 0.618
# epsilon: 0.237
# average lifetime: 24.958
# -------------------------------
# frame count: 399360
# average reward: 0.818
# epsilon: 0.209
# average lifetime: 28.214
# -------------------------------
# frame count: 416211
# average reward: 1.178
# epsilon: 0.176
# average lifetime: 33.702
# -------------------------------
# frame count: 435002
# average reward: 1.448
# epsilon: 0.139
# average lifetime: 37.582
# -------------------------------
# frame count: 455486
# average reward: 1.744
# epsilon: 0.098
# average lifetime: 40.968
# -------------------------------
# frame count: 495739
# average reward: 3.498
# epsilon: 0.018
# average lifetime: 80.506
# -------------------------------
# frame count: 620335
# average reward: 7.344
# epsilon: 0.01
# average lifetime: 249.192
# -------------------------------
# frame count: 719789
# average reward: 8.176
# epsilon: 0.01
# average lifetime: 198.908
# -------------------------------
# frame count: 841643
# average reward: 10.366
# epsilon: 0.01
# average lifetime: 243.708
# -------------------------------
# frame count: 949912
# average reward: 12.122
# epsilon: 0.01
# average lifetime: 216.538
# -------------------------------
# frame count: 1069848
# average reward: 13.418
# epsilon: 0.01
# average lifetime: 239.872
# -------------------------------
# frame count: 1191856
# average reward: 13.874
# epsilon: 0.01
# average lifetime: 244.016
# -------------------------------
# frame count: 1318994
# average reward: 14.224
# epsilon: 0.01
# average lifetime: 254.276
# -------------------------------
# frame count: 1441221
# average reward: 13.43
# epsilon: 0.01
# average lifetime: 244.454
# -------------------------------
# frame count: 1573068
# average reward: 14.66
# epsilon: 0.01
# average lifetime: 263.694
# -------------------------------

# %% [markdown]
# # Visualization

# %%
aa.play(gpu_id=2, max_episode_length=100, from_epoch=234)
